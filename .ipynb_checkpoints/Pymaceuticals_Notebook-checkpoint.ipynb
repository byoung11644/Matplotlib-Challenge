# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
#Read in Data, Merge the DF, and Preview.dup
mouse_metadata_path = "Pymaceuticals\\data\\Mouse_metadata.csv"
study_results_path = "Pymaceuticals\\data\\Study_results.csv"

mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

study_df = pd.merge(study_results, mouse_metadata, on="Mouse ID", how="left")
study_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1       Male          15          29
# 2     Female           2          29
# 3     Female          11          30
# 4       Male          21          25
# ...      ...         ...         ...
# 1888    Male          12          25
# 1889    Male          18          17
# 1890  Female          11          26
# 1891  Female          21          30
# 1892  Female           4          26
#
# [1893 rows x 8 columns]

# %%
#Check if any NaN
study_df.count()
# Out:
# Mouse ID              1893
# Timepoint             1893
# Tumor Volume (mm3)    1893
# Metastatic Sites      1893
# Drug Regimen          1893
# Sex                   1893
# Age_months            1893
# Weight (g)            1893
# dtype: int64

# %%
#Check how many mice we have
len(pd.unique(study_df['Mouse ID']))
# Out:
# 249

# %%
#Find the duplicates
duplicate_entries = study_df[study_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_entries
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
#Drop duplicates
complete_study = study_df.drop_duplicates(['Mouse ID', 'Timepoint'], keep='first')

# %%
#Make sure no more duplicates
duplicate_entries = complete_study[complete_study.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_entries
# Out:
# Empty DataFrame
# Columns: [Mouse ID, Timepoint, Tumor Volume (mm3), Metastatic Sites, Drug Regimen, Sex, Age_months, Weight (g)]
# Index: []

# %%
#Check how many entries we now have
complete_study.count()
# Out:
# Mouse ID              1888
# Timepoint             1888
# Tumor Volume (mm3)    1888
# Metastatic Sites      1888
# Drug Regimen          1888
# Sex                   1888
# Age_months            1888
# Weight (g)            1888
# dtype: int64

# %%
#Create summary statistics table
complete_study.describe()
# Out:
#          Timepoint  Tumor Volume (mm3)  Metastatic Sites   Age_months  \
# count  1888.000000         1888.000000       1888.000000  1888.000000
# mean     19.597458           50.449276          1.023835    12.792903
# std      14.084762            8.904565          1.138507     7.186737
# min       0.000000           22.050126          0.000000     1.000000
# 25%       5.000000           45.000000          0.000000     7.000000
# 50%      20.000000           48.951421          1.000000    13.000000
# 75%      30.000000           56.324075          2.000000    20.000000
# max      45.000000           78.567014          4.000000    24.000000
#
#         Weight (g)
# count  1888.000000
# mean     25.661547
# std       3.926776
# min      15.000000
# 25%      25.000000
# 50%      27.000000
# 75%      29.000000
# max      30.000000

# %%
#Create Grouping by Drug Regimen and Summary Table
drug_grouping = complete_study.groupby(['Drug Regimen'])
Tumor_Volume_by_Drug = drug_grouping['Tumor Volume (mm3)']

# %%
#Calculate the fields
mean = Tumor_Volume_by_Drug.mean()
stnd = Tumor_Volume_by_Drug.std()
sems = Tumor_Volume_by_Drug.sem()
median = Tumor_Volume_by_Drug.median()
var = Tumor_Volume_by_Drug.var()

#Rename Series
Tumor_Mean = mean.rename("Mean")
Tumor_Median = median.rename("Median")
Tumor_STD = stnd.rename("STD")
Tumor_Var = var.rename("Variance")
Tumor_SEM = sems.rename("SEM")

summary_stats = {'Mean': Tumor_Mean, 'Median': Tumor_Median, 'STD': Tumor_STD, 'Variance': Tumor_Var, 'SEM': Tumor_SEM}
Drug_Regimen_Summary = pd.DataFrame(summary_stats)
Drug_Regimen_Summary
# Out:
#                    Mean     Median       STD   Variance       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  4.994774  24.947764  0.329346
# Ceftamin      52.591172  51.776157  6.268188  39.290177  0.469821
# Infubinol     52.884795  51.820584  6.567243  43.128684  0.492236
# Ketapril      55.235638  53.698743  8.279709  68.553577  0.603860
# Naftisol      54.331565  52.509285  8.134708  66.173479  0.596466
# Placebo       54.033581  52.288934  7.821003  61.168083  0.581331
# Propriva      52.393463  50.909965  6.568014  43.138803  0.525862
# Ramicane      40.216745  40.673236  4.846308  23.486704  0.320955
# Stelasyn      54.233149  52.431737  7.710419  59.450562  0.573111
# Zoniferol     53.236507  51.818479  6.966589  48.533355  0.516398

# %%
#PyPlot bar chart
mice_counts = drug_grouping['Mouse ID'].count()
x_axis = pd.unique(study_df['Drug Regimen'])
plt.bar(x_axis, mice_counts)
plt.xticks(rotation=90)
plt.show()

# %%
#DataFrame plot
Drug_Counts = pd.DataFrame(drug_grouping['Mouse ID'].count())
Drug_Counts.plot(kind="bar")

# %%
#Gender Grouping
gender_grouping = mouse_metadata.groupby(['Sex'])
Gender_Counts = gender_grouping['Sex'].count()

#PyPlot Pie
values = Gender_Counts
labels = pd.unique(Gender_Counts.index)
plt.pie(values, labels=labels, colors=["lightcoral", "lightskyblue"], autopct="%1.1f%%", shadow=True)
plt.axis("equal")
plt.show()

# %%
#DataFrame Pie
Gender_DF = pd.DataFrame(gender_grouping['Sex'].count())
#Gender_DF.plot(kind="pie")
plot = Gender_DF.plot.pie(y='Sex', colors=["lightcoral", "lightskyblue"], figsize=(5,5), shadow = True, autopct='%1.1f%%')

# %%
#Get final Timepoint for each mouse
mouse_group = complete_study.groupby(['Mouse ID'])
mouse_group['Timepoint'].max()
# Out:
# Mouse ID
# a203    45
# a251    45
# a262    45
# a275    45
# a366    30
#         ..
# z435    10
# z578    45
# z581    45
# z795    45
# z969    45
# Name: Timepoint, Length: 249, dtype: int64

# %%
#Merge the final Timepoint for each mouse back into complete table
#Then, drop the NaN values for data points not at that mouse's final timepoint
final_timepoint_merge = pd.merge(complete_study, mouse_group.max(), on=["Mouse ID", 'Timepoint'], how="left")
final_timepoint = final_timepoint_merge.dropna()
final_timepoint
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)_x  Metastatic Sites_x  \
# 1        f932          0             45.000000                   0
# 20       x336          0             45.000000                   0
# 53       h428          0             45.000000                   0
# 55       v199          0             45.000000                   0
# 109      o848          0             45.000000                   0
# ...       ...        ...                   ...                 ...
# 1883     r944         45             41.581521                   2
# 1884     u364         45             31.023923                   3
# 1885     p438         45             61.433892                   1
# 1886     x773         45             58.634971                   4
# 1887     b879         45             72.555239                   2
#
#      Drug Regimen_x   Sex_x  Age_months_x  Weight (g)_x  Tumor Volume (mm3)_y  \
# 1          Ketapril    Male            15            29             45.000000
# 20         Naftisol  Female             4            29             45.000000
# 53         Ketapril  Female             1            27             45.000000
# 55         Naftisol  Female            17            29             45.000000
# 109        Stelasyn  Female            14            27             45.000000
# ...             ...     ...           ...           ...                   ...
# 1883      Capomulin    Male            12            25             47.373423
# 1884      Capomulin    Male            18            17             47.212200
# 1885       Ceftamin  Female            11            26             61.433892
# 1886        Placebo  Female            21            30             58.634971
# 1887       Stelasyn  Female             4            26             72.555239
#
#       Metastatic Sites_y Drug Regimen_y   Sex_y  Age_months_y  Weight (g)_y
# 1                    0.0       Ketapril    Male          15.0          29.0
# 20                   0.0       Naftisol  Female           4.0          29.0
# 53                   0.0       Ketapril  Female           1.0          27.0
# 55                   0.0       Naftisol  Female          17.0          29.0
# 109                  0.0       Stelasyn  Female          14.0          27.0
# ...                  ...            ...     ...           ...           ...
# 1883                 2.0      Capomulin    Male          12.0          25.0
# 1884                 3.0      Capomulin    Male          18.0          17.0
# 1885                 1.0       Ceftamin  Female          11.0          26.0
# 1886                 4.0        Placebo  Female          21.0          30.0
# 1887                 2.0       Stelasyn  Female           4.0          26.0
#
# [249 rows x 14 columns]

# %%
#Get the final volumes for each of the promising regimens

promising_studies = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
final_timepoint = final_timepoint[final_timepoint['Drug Regimen_y'].isin(promising_studies)]

final_timepoint
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)_x  Metastatic Sites_x  \
# 181      u153          0             45.000000                   0
# 193      b447          0             45.000000                   0
# 216      x226          0             45.000000                   0
# 221      t573          0             45.000000                   0
# 418      c326          5             36.321346                   0
# ...       ...        ...                   ...                 ...
# 1874     a644         45             32.978522                   1
# 1880     i177         45             33.562402                   3
# 1883     r944         45             41.581521                   2
# 1884     u364         45             31.023923                   3
# 1885     p438         45             61.433892                   1
#
#      Drug Regimen_x   Sex_x  Age_months_x  Weight (g)_x  Tumor Volume (mm3)_y  \
# 181        Ceftamin  Female            11            25             45.000000
# 193        Ceftamin    Male             2            30             45.000000
# 216        Ceftamin    Male            23            28             45.000000
# 221        Ceftamin  Female            15            27             45.000000
# 418       Infubinol  Female            18            25             45.000000
# ...             ...     ...           ...           ...                   ...
# 1874       Ramicane  Female             7            17             46.910892
# 1880       Ramicane    Male            10            18             45.000000
# 1883      Capomulin    Male            12            25             47.373423
# 1884      Capomulin    Male            18            17             47.212200
# 1885       Ceftamin  Female            11            26             61.433892
#
#       Metastatic Sites_y Drug Regimen_y   Sex_y  Age_months_y  Weight (g)_y
# 181                  0.0       Ceftamin  Female          11.0          25.0
# 193                  0.0       Ceftamin    Male           2.0          30.0
# 216                  0.0       Ceftamin    Male          23.0          28.0
# 221                  0.0       Ceftamin  Female          15.0          27.0
# 418                  0.0      Infubinol  Female          18.0          25.0
# ...                  ...            ...     ...           ...           ...
# 1874                 1.0       Ramicane  Female           7.0          17.0
# 1880                 3.0       Ramicane    Male          10.0          18.0
# 1883                 2.0      Capomulin    Male          12.0          25.0
# 1884                 3.0      Capomulin    Male          18.0          17.0
# 1885                 1.0       Ceftamin  Female          11.0          26.0
#
# [100 rows x 14 columns]

# %%
final_promising_group = final_timepoint.groupby('Drug Regimen_y')
final_promising_group.sum()
# Out:
#                 Timepoint  Tumor Volume (mm3)_x  Metastatic Sites_x  \
# Drug Regimen_y
# Capomulin            1025            916.689193                  32
# Ceftamin              765           1443.849421                  43
# Infubinol             765           1454.456145                  40
# Ramicane             1015            904.784761                  30
#
#                 Age_months_x  Weight (g)_x  Tumor Volume (mm3)_y  \
# Drug Regimen_y
# Capomulin                351           503           1152.979972
# Ceftamin                 320           685           1443.849421
# Infubinol                410           683           1463.134799
# Ramicane                 271           500           1141.966116
#
#                 Metastatic Sites_y  Age_months_y  Weight (g)_y
# Drug Regimen_y
# Capomulin                     32.0         351.0         503.0
# Ceftamin                      43.0         320.0         685.0
# Infubinol                     40.0         410.0         683.0
# Ramicane                      30.0         271.0         500.0

# %%
#all_tumor_volumes = []
#for drug in promising_studies:
#    list = []
#    for i in final_timepoint.index:
#        if final_timepoint['Drug Regimen_y'][i] == drug:
#            list = list.append(['Tumor Volume (mm3)_y'][i])
#        else:
#            next
#    all_tumor_volumes = all_tmmor_volumes.append(list)
#    next

    
#all_tumor_volumes

# %%
#promising_studies = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]


Capomulin_df = final_timepoint.loc[final_timepoint['Drug Regimen_y'] == "Capomulin"]
Ramicane_df = final_timepoint.loc[final_timepoint['Drug Regimen_y'] == "Ramicane"]
Infubinol_df = final_timepoint.loc[final_timepoint['Drug Regimen_y'] == "Infubinol"]
Ceftamin_df = final_timepoint.loc[final_timepoint['Drug Regimen_y'] == "Ceftamin"]

# %%
#Calculate the quartile and IQR for each of the promising regimens
quartiles = california_data['AveOccup'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq
